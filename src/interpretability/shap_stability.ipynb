# %%
import pickle
import numpy as np

# %% [markdown]
# # Get the data

# %%
print("Unimodal")
results = {}
for k in [5, 10, 20, 30]:
    means = []
    results = f"& $k  = {k}$ "
    for i in range(5):
        shap_results_fold_dir = f'../results/ablations/dss_survival_brca/DIMAFx/Fold_{i}/post_training/shap/modal/shap_stability_modal.pkl'
        shap_stab_dict = pickle.load(open(shap_results_fold_dir, 'rb'))     
        results += f"& {shap_stab_dict[f'Top_{k}']['mean']:.3f}±{shap_stab_dict[f'Top_{k}']['std']:.3f} "
        means.append(shap_stab_dict[f'Top_{k}']['mean'])

    mean_over_folds = np.mean(means)
    std_over_folds = np.std(means)
    results += f"& {mean_over_folds:.3f}±{std_over_folds:.3f} \\\\"

    
    print(results)
# Out:
# Unimodal
# & $k  = 5$ & 0.822±0.174 & 0.836±0.167 & 1.000±0.000 & 0.699±0.177 & 0.647±0.179 & 0.801±0.123 \\
# & $k  = 10$ & 0.956±0.079 & 0.858±0.090 & 0.893±0.096 & 0.953±0.086 & 0.915±0.097 & 0.915±0.037 \\
# & $k  = 20$ & 0.927±0.060 & 0.918±0.053 & 0.980±0.039 & 0.942±0.048 & 0.952±0.052 & 0.944±0.022 \\
# & $k  = 30$ & 0.905±0.045 & 0.918±0.040 & 0.884±0.048 & 0.900±0.043 & 0.913±0.041 & 0.904±0.012 \\

# %%
print("Multimodal")
results = {}

for k in [5, 10, 20, 30]:
    means = []
    results = f"& $k  = {k}$ "
    for i in range(5):
        shap_results_fold_dir = f'../results/ablations/dss_survival_brca/DIMAFx/Fold_{i}/post_training/shap/post_attn/shap_stability_post_attn.pkl'
        shap_stab_dict = pickle.load(open(shap_results_fold_dir, 'rb'))     
        results += f"& {shap_stab_dict[f'Top_{k}']['mean']:.3f}±{shap_stab_dict[f'Top_{k}']['std']:.3f} "
        means.append(shap_stab_dict[f'Top_{k}']['mean'])

    mean_over_folds = np.mean(means)
    std_over_folds = np.std(means)
    results += f"& {mean_over_folds:.3f}±{std_over_folds:.3f} \\\\"

    
    print(results)
# Out:
# Multimodal
# & $k  = 5$ & 0.993±0.047 & 0.813±0.165 & 0.938±0.130 & 0.628±0.214 & 1.000±0.000 & 0.875±0.140 \\
# & $k  = 10$ & 0.842±0.108 & 1.000±0.000 & 0.873±0.120 & 0.640±0.166 & 0.904±0.091 & 0.852±0.118 \\
# & $k  = 20$ & 0.894±0.064 & 0.993±0.026 & 0.936±0.062 & 0.780±0.129 & 0.919±0.052 & 0.904±0.070 \\
# & $k  = 30$ & 0.958±0.034 & 0.955±0.031 & 0.974±0.037 & 0.854±0.094 & 0.953±0.034 & 0.939±0.043 \\

# %%
shap_stab_dict
# Out:
# {'Top_5': {'mean': 1.0, 'std': 0.0},
#  'Top_10': {'mean': 0.9036179981634529, 'std': 0.09074420122463737},
#  'Top_20': {'mean': 0.9187459005640826, 'std': 0.05166331568612572},
#  'Top_30': {'mean': 0.9529797239254718, 'std': 0.03353812300918523}}
